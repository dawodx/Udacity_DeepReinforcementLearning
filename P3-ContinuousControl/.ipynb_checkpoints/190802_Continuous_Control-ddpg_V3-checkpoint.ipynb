# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %%
env = UnityEnvironment(file_name='Reacher.app')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
env = UnityEnvironment(file_name="Reacher_multi.app")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# When finished, you can close the environment.

# %%
#=============================================================
#================ Libraraies =========================
#=============================================================
import random
import copy
import os
from collections import namedtuple, deque

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#=============================================================
#================ The Network  Model =========================
#=============================================================

def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, fc1_units=400, fc2_units=300):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        """Build an actor (policy) network that maps states -> actions."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return F.tanh(self.fc3(x))


class Critic(nn.Module):
    """Critic (Value) Model."""

    def __init__(self, state_size, action_size, seed, fcs1_units=400, fc2_units=300):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fcs1_units (int): Number of nodes in the first hidden layer
            fc2_units (int): Number of nodes in the second hidden layer
        """
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fcs1 = nn.Linear(state_size, fcs1_units)
        self.fc2 = nn.Linear(fcs1_units+action_size, fc2_units)
        self.fc3 = nn.Linear(fc2_units, 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcs1.weight.data.uniform_(*hidden_init(self.fcs1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
        xs = F.relu(self.fcs1(state))
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.fc2(x))
        return self.fc3(x)



device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


#=============================================================
#=================== The Agent Class =========================
#=============================================================

class Agent():
    """Interacts with and learns from the environment."""
    
    def __init__(self, state_size, action_size, random_seed,buffer_size, batch_size,gamma, TAU,
                 lr_actor, lr_critic, weight_decay, actor_hl1, actor_hl2, critic_hl1, critic_hl2, checkpoint_folder):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            random_seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)
        
        # Hyperparameters
        self.BUFFER_SIZE = buffer_size
        self.BATCH_SIZE = batch_size
        self.GAMMA = gamma
        self.TAU = TAU
        self.LR_ACTOR = lr_actor
        self.LR_CRITIC = lr_critic
        self.WEIGHT_DECAY = weight_decay
        self.ACTOR_HL_1= actor_hl1          
        self.ACTOR_HL_2= actor_hl2          
        self.CRITIC_HL_1= critic_hl1 
        self.CRITIC_HL_2= critic_hl2  
        self.CHECKPOINT_FOLDER = checkpoint_folder
        

        # Actor Network (w/ Target Network)
        self.actor_local = Actor(state_size, action_size, random_seed,self.ACTOR_HL_1,self.ACTOR_HL_2).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed,self.ACTOR_HL_1,self.ACTOR_HL_2).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=self.LR_ACTOR)

        # Critic Network (w/ Target Network)
        self.critic_local = Critic(state_size, action_size, random_seed, self.CRITIC_HL_1, self.CRITIC_HL_2).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed, self.CRITIC_HL_1, self.CRITIC_HL_2).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=self.LR_CRITIC, weight_decay= self.WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)

        # Replay memory
        self.memory = ReplayBuffer(action_size, self.BUFFER_SIZE, self.BATCH_SIZE, random_seed)
        
        #Load a trained agent model 
        if os.path.isfile(self.CHECKPOINT_FOLDER + 'checkpoint_actor.pth') and os.path.isfile(self.CHECKPOINT_FOLDER + 'checkpoint_critic.pth'):
            self.actor_local.load_state_dict(torch.load(self.CHECKPOINT_FOLDER + 'checkpoint_actor.pth'))
            self.actor_target.load_state_dict(torch.load(self.CHECKPOINT_FOLDER + 'checkpoint_actor.pth'))

            self.critic_local.load_state_dict(torch.load(self.CHECKPOINT_FOLDER + 'checkpoint_critic.pth'))
            self.critic_target.load_state_dict(torch.load(self.CHECKPOINT_FOLDER + 'checkpoint_critic.pth'))
    
    def step(self, state, action, reward, next_state, done):
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        self.memory.add(state, action, reward, next_state, done)

        # Learn, if enough samples are available in memory
        if len(self.memory) > self.BATCH_SIZE:
            experiences = self.memory.sample()
            self.learn(experiences, self.GAMMA)

    def act(self, state, add_noise=True):
        """Returns actions for given state as per current policy."""
        state = torch.from_numpy(state).float().to(device)
        self.actor_local.eval()
        with torch.no_grad():
            action = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        if add_noise:
            action += self.noise.sample()
        return np.clip(action, -1, 1)

    def reset(self):
        self.noise.reset()

    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples.
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value

        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        #torch.nn.utils.clip_grad_norm(self.critic_local.parameters(), 1)
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.soft_update(self.critic_local, self.critic_target, self.TAU)
        self.soft_update(self.actor_local, self.actor_target, self.TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)
    
    def checkpoint (self):
        torch.save(self.actor_local.state_dict(), self.CHECKPOINT_FOLDER + 'checkpoint_actor.pth')
        torch.save(self.critic_local.state_dict(), self.CHECKPOINT_FOLDER + 'checkpoint_critic.pth')
        

class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ### 4. Train Agent

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def ddpg_train(n_episodes=500, max_t=10000, print_every=20):
    scores_deque = deque(maxlen=print_every)
    scores_list = []
    
    for i_episode in range(1, n_episodes+1):
        
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        states = env_info.vector_observations
        
        scores = np.zeros(num_agents)

        for t in range(max_t):
            agent.reset()
            actions = []
            for i_agent in range(num_agents):
                actions.append(agent.act(states[i_agent]))
            
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            for i_agent in range(num_agents):
                agent.step(states[i_agent], actions[i_agent],
                                     rewards[i_agent], next_states[i_agent],
                                     dones[i_agent])
            
            states = next_states
            scores += rewards
            if np.any(dones):
                break 
        
        scores_deque.append(np.mean(scores))
        scores_list.append(np.mean(scores))
        
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)), end="")
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
        
        if np.mean(scores_deque) >= 30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode, np.mean(scores_deque)))
            agent.checkpoint()
            break
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(1, len(scores_list)+1), scores_list)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()
   # env.close()

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================


#================ Hyperpramters =========================

BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 64        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_1= 256          #Actor Hidden layer 1
ACTOR_HL_2= 128          #Actor Hidden layer 1

CRITIC_HL_1= 256          #Actor Hidden layer 1
CRITIC_HL_2= 128          #Actor Hidden layer 1

CHECKPOINT_FOLDER = './model/'
        
#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (state_size, action_size, 4,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_1, ACTOR_HL_2, CRITIC_HL_1, CRITIC_HL_2, CHECKPOINT_FOLDER)
ddpg_train()
# Out:
# Episode 20	Average Score: 0.94
# Episode 40	Average Score: 1.66
# Episode 60	Average Score: 2.09
# Episode 80	Average Score: 2.35
# Episode 100	Average Score: 2.88
# Episode 120	Average Score: 3.17
# Episode 140	Average Score: 4.27
# Episode 160	Average Score: 5.08
# Episode 180	Average Score: 5.40
# Episode 200	Average Score: 5.58
# Episode 220	Average Score: 6.60
# Episode 240	Average Score: 7.20
# Episode 260	Average Score: 6.48
# Episode 280	Average Score: 8.11
# Episode 300	Average Score: 6.55
# Episode 320	Average Score: 7.88
# Episode 340	Average Score: 8.96
# Episode 360	Average Score: 10.64
# Episode 380	Average Score: 8.375
# Episode 400	Average Score: 8.76
# Episode 420	Average Score: 10.42
# Episode 440	Average Score: 8.532
# Episode 460	Average Score: 8.91
# Episode 480	Average Score: 6.96
# Episode 500	Average Score: 7.55

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================


#================ Hyperpramters =========================

BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 128        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_1= 256          #Actor Hidden layer 1
ACTOR_HL_2= 128          #Actor Hidden layer 1

CRITIC_HL_1= 256          #Actor Hidden layer 1
CRITIC_HL_2= 128          #Actor Hidden layer 1

CHECKPOINT_FOLDER = './model_2/'

#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (state_size, action_size, 4,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_1, ACTOR_HL_2, CRITIC_HL_1, CRITIC_HL_2, CHECKPOINT_FOLDER)
ddpg_train()
# Out:
# Episode 20	Average Score: 1.02
# Episode 40	Average Score: 1.75
# Episode 60	Average Score: 3.07
# Episode 80	Average Score: 2.77
# Episode 100	Average Score: 3.96
# Episode 120	Average Score: 4.74
# Episode 140	Average Score: 4.65
# Episode 160	Average Score: 5.66
# Episode 180	Average Score: 5.98
# Episode 200	Average Score: 7.56
# Episode 220	Average Score: 7.37
# Episode 240	Average Score: 8.69
# Episode 260	Average Score: 9.00
# Episode 280	Average Score: 8.19
# Episode 300	Average Score: 8.57
# Episode 320	Average Score: 8.73
# Episode 340	Average Score: 7.08
# Episode 360	Average Score: 8.68
# Episode 380	Average Score: 9.11
# Episode 400	Average Score: 11.75
# Episode 420	Average Score: 11.45
# Episode 440	Average Score: 9.630
# Episode 460	Average Score: 9.61
# Episode 480	Average Score: 8.992
# Episode 500	Average Score: 14.04

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================


#================ Hyperpramters =========================

BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 128        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_1= 256          #Actor Hidden layer 1
ACTOR_HL_2= 128          #Actor Hidden layer 1

CRITIC_HL_1= 256          #Actor Hidden layer 1
CRITIC_HL_2= 128          #Actor Hidden layer 1

CHECKPOINT_FOLDER = './model_2/'

#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (state_size, action_size, 4,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_1, ACTOR_HL_2, CRITIC_HL_1, CRITIC_HL_2, CHECKPOINT_FOLDER)
ddpg_train()
# Out:
# Episode 20	Average Score: 0.42
# Episode 40	Average Score: 1.10
# Episode 60	Average Score: 1.57
# Episode 80	Average Score: 2.21
# Episode 100	Average Score: 3.30
# Episode 120	Average Score: 2.87
# Episode 140	Average Score: 3.17
# Episode 160	Average Score: 3.83
# Episode 180	Average Score: 4.62
# Episode 200	Average Score: 4.19
# Episode 220	Average Score: 3.84
# Episode 240	Average Score: 3.65
# Episode 260	Average Score: 3.92
# Episode 280	Average Score: 2.36
# Episode 300	Average Score: 3.49
# Episode 320	Average Score: 3.94
# Episode 340	Average Score: 3.05
# Episode 360	Average Score: 2.67
# Episode 380	Average Score: 2.23
# Episode 400	Average Score: 2.69
# Episode 420	Average Score: 2.13
# Episode 440	Average Score: 2.31
# Episode 460	Average Score: 2.10
# Episode 480	Average Score: 1.38
# Episode 500	Average Score: 1.67

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================


#================ Hyperpramters =========================

BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 128        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_1= 400          #Actor Hidden layer 1
ACTOR_HL_2= 300          #Actor Hidden layer 1

CRITIC_HL_1= 400          #Actor Hidden layer 1
CRITIC_HL_2= 300          #Actor Hidden layer 1

CHECKPOINT_FOLDER = './model_2/'

#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (state_size, action_size, 4,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_1, ACTOR_HL_2, CRITIC_HL_1, CRITIC_HL_2, CHECKPOINT_FOLDER)
ddpg_train()
# Out:
# Episode 20	Average Score: 0.64
# Episode 40	Average Score: 1.59
# Episode 60	Average Score: 1.69
# Episode 80	Average Score: 1.76
# Episode 100	Average Score: 2.24
# Episode 120	Average Score: 2.66
# Episode 140	Average Score: 2.29
# Episode 160	Average Score: 3.13
# Episode 180	Average Score: 2.89
# Episode 200	Average Score: 2.76
# Episode 220	Average Score: 2.93
# Episode 240	Average Score: 3.36
# Episode 260	Average Score: 3.04
# Episode 280	Average Score: 2.81
# Episode 300	Average Score: 2.65
# Episode 320	Average Score: 2.89
# Episode 340	Average Score: 2.89
# Episode 360	Average Score: 2.06
# Episode 380	Average Score: 2.02
# Episode 400	Average Score: 2.19
# Episode 420	Average Score: 1.64
# Episode 440	Average Score: 1.98
# Episode 460	Average Score: 1.58
# Episode 480	Average Score: 1.80
# Episode 500	Average Score: 1.72

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def ddpg_train(n_episodes=500, max_t=10000, print_every=20):
    scores_deque = deque(maxlen=print_every)
    scores_list = []
    
    for i_episode in range(1, n_episodes+1):
        
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        states = env_info.vector_observations
        
        scores = np.zeros(num_agents)

        while True:
            agent.reset()
            actions = []
            for i_agent in range(num_agents):
                actions.append(agent.act(states[i_agent]))
            
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            for i_agent in range(num_agents):
                agent.step(states[i_agent], actions[i_agent],
                                     rewards[i_agent], next_states[i_agent],
                                     dones[i_agent])
            
            states = next_states
            scores += rewards
            if np.any(dones):
                break 
        
        scores_deque.append(np.mean(scores))
        scores_list.append(np.mean(scores))
        
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)), end="")
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
        
        if np.mean(scores_deque) >= 30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode, np.mean(scores_deque)))
            agent.checkpoint()
            break
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(1, len(scores_list)+1), scores_list)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()
   # env.close()

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================


#================ Hyperpramters =========================

BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 64        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_1= 256          #Actor Hidden layer 1
ACTOR_HL_2= 128          #Actor Hidden layer 1

CRITIC_HL_1= 256          #Actor Hidden layer 1
CRITIC_HL_2= 128          #Actor Hidden layer 1

CHECKPOINT_FOLDER = './model_2/'

#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (state_size, action_size, 4,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_1, ACTOR_HL_2, CRITIC_HL_1, CRITIC_HL_2, CHECKPOINT_FOLDER)
ddpg_train()
# Out:
# Episode 20	Average Score: 0.76
# Episode 40	Average Score: 1.98
# Episode 60	Average Score: 2.83
# Episode 80	Average Score: 3.51
# Episode 100	Average Score: 4.67
# Episode 120	Average Score: 4.93
# Episode 140	Average Score: 5.85
# Episode 160	Average Score: 5.99
# Episode 180	Average Score: 7.06
# Episode 200	Average Score: 5.70
# Episode 220	Average Score: 6.48
# Episode 240	Average Score: 6.56
# Episode 260	Average Score: 5.98
# Episode 280	Average Score: 5.20
# Episode 300	Average Score: 6.18
# Episode 320	Average Score: 6.91
# Episode 340	Average Score: 5.92
# Episode 360	Average Score: 8.02
# Episode 380	Average Score: 6.49
# Episode 400	Average Score: 7.41
# Episode 420	Average Score: 5.81
# Episode 440	Average Score: 6.03
# Episode 460	Average Score: 6.04
# Episode 480	Average Score: 5.56
# Episode 500	Average Score: 6.75

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def ddpg_train(n_episodes=300, max_t=1000, print_every=100):
    scores_deque = deque(maxlen=print_every)
    scores_list = []
    
    for i_episode in range(1, n_episodes+1):
        
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        states = env_info.vector_observations
        scores = np.zeros(num_agents)
        agent.reset()
        for t in range(max_t): 
            actions = []
            for i_agent in range(num_agents):
                actions.append(agent.act(states[i_agent]))
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            for i_agent in range(num_agents):
                agent.step(states[i_agent], actions[i_agent],
                                     rewards[i_agent], next_states[i_agent],
                                     dones[i_agent])
            states = next_states
            scores += rewards
            if np.any(dones):
                print('\tSteps: ', t)
                break 
        
        scores_deque.append(np.mean(scores))
        scores_list.append(np.mean(scores))
        
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)), end="")
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
        
        if np.mean(scores_deque) >= 30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode, np.mean(scores_deque)))
            agent.checkpoint()
            break
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(1, len(scores_list)+1), scores_list)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================


#================ Hyperpramters =========================

BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 128        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_1= 256          #Actor Hidden layer 1
ACTOR_HL_2= 128          #Actor Hidden layer 1

CRITIC_HL_1= 256          #Actor Hidden layer 1
CRITIC_HL_2= 128          #Actor Hidden layer 1

CHECKPOINT_FOLDER = './model_2/'

#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (state_size, action_size, 0,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_1, ACTOR_HL_2, CRITIC_HL_1, CRITIC_HL_2, CHECKPOINT_FOLDER)
ddpg_train()
# Out:
# Episode 76	Average Score: 1.98

# %%
#=============================================================
#================ Libraraies =========================
#=============================================================
import random
import copy
import os
from collections import namedtuple, deque

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#=============================================================
#================ The Network  Model =========================
#=============================================================

def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, fc1_units=400, fc2_units=300):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        """Build an actor (policy) network that maps states -> actions."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return F.tanh(self.fc3(x))


class Critic(nn.Module):
    """Critic (Value) Model."""

    def __init__(self, state_size, action_size, seed, fcs1_units=400, fc2_units=300):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fcs1_units (int): Number of nodes in the first hidden layer
            fc2_units (int): Number of nodes in the second hidden layer
        """
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fcs1 = nn.Linear(state_size, fcs1_units)
        self.fc2 = nn.Linear(fcs1_units+action_size, fc2_units)
        self.fc3 = nn.Linear(fc2_units, 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcs1.weight.data.uniform_(*hidden_init(self.fcs1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
        xs = F.relu(self.fcs1(state))
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.fc2(x))
        return self.fc3(x)






#=============================================================
#=================== The Agent Class =========================
#=============================================================

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
 

class Agent():
    """Interacts with and learns from the environment."""
    
    def __init__(self, state_size, action_size, random_seed,buffer_size, batch_size,gamma, TAU,
                 lr_actor, lr_critic, weight_decay, actor_hl1, actor_hl2, critic_hl1, critic_hl2, checkpoint_folder):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            random_seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)
        
        # Hyperparameters
        self.BUFFER_SIZE = buffer_size
        self.BATCH_SIZE = batch_size
        self.GAMMA = gamma
        self.TAU = TAU
        self.LR_ACTOR = lr_actor
        self.LR_CRITIC = lr_critic
        self.WEIGHT_DECAY = weight_decay
        self.ACTOR_HL_1= actor_hl1          
        self.ACTOR_HL_2= actor_hl2          
        self.CRITIC_HL_1= critic_hl1 
        self.CRITIC_HL_2= critic_hl2  
        self.CHECKPOINT_FOLDER = checkpoint_folder
        
        self.UPDATE_EVERY =20
        #self.t_step = 0

        # Actor Network (w/ Target Network)
        self.actor_local = Actor(state_size, action_size, random_seed,self.ACTOR_HL_1,self.ACTOR_HL_2).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed,self.ACTOR_HL_1,self.ACTOR_HL_2).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=self.LR_ACTOR)

        # Critic Network (w/ Target Network)
        self.critic_local = Critic(state_size, action_size, random_seed, self.CRITIC_HL_1, self.CRITIC_HL_2).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed, self.CRITIC_HL_1, self.CRITIC_HL_2).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=self.LR_CRITIC, weight_decay= self.WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)

        # Replay memory
        self.memory = ReplayBuffer(action_size, self.BUFFER_SIZE, self.BATCH_SIZE, random_seed)
        
        #Load a trained agent model 
        if os.path.isfile(self.CHECKPOINT_FOLDER + 'checkpoint_actor.pth') and os.path.isfile(self.CHECKPOINT_FOLDER + 'checkpoint_critic.pth'):
            self.actor_local.load_state_dict(torch.load(self.CHECKPOINT_FOLDER + 'checkpoint_actor.pth'))
            self.actor_target.load_state_dict(torch.load(self.CHECKPOINT_FOLDER + 'checkpoint_actor.pth'))

            self.critic_local.load_state_dict(torch.load(self.CHECKPOINT_FOLDER + 'checkpoint_critic.pth'))
            self.critic_target.load_state_dict(torch.load(self.CHECKPOINT_FOLDER + 'checkpoint_critic.pth'))
    
    def step(self, state, action, reward, next_state, done):
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        self.memory.add(state, action, reward, next_state, done)
    
    
    #def update_t_step(self):
        #self.t_step = (self.t_step + 1)
        
    def step_learn(self):
        # Learn every UPDATE_EVERY time steps.
        #self.t_step = self.t_step % self.UPDATE_EVERY
        #if self.t_step == 0:
            # Learn, if enough samples are available in memory
        if len(self.memory) > self.BATCH_SIZE:
            experiences = self.memory.sample()
            self.learn(experiences, self.GAMMA)
        

    def act(self, state, add_noise=True):
        """Returns actions for given state as per current policy."""
        state = torch.from_numpy(state).float().to(device)
        self.actor_local.eval()
        with torch.no_grad():
            action = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        if add_noise:
            action += self.noise.sample()
        return np.clip(action, -1, 1)

    def reset(self):
        self.noise.reset()

    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples.
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value

        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        #torch.nn.utils.clip_grad_norm(self.critic_local.parameters(), 1)
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.soft_update(self.critic_local, self.critic_target, self.TAU)
        self.soft_update(self.actor_local, self.actor_target, self.TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)
    
    def checkpoint (self):
        torch.save(self.actor_local.state_dict(), self.CHECKPOINT_FOLDER + 'checkpoint_actor.pth')
        torch.save(self.critic_local.state_dict(), self.CHECKPOINT_FOLDER + 'checkpoint_critic.pth')
        

class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def ddpg_train(n_episodes=300, max_t=1000, print_every=100):
    scores_deque = deque(maxlen=print_every)
    scores_list = []
    
    for i_episode in range(1, n_episodes+1):
        
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        states = env_info.vector_observations
        scores = np.zeros(num_agents)
        agent.reset()
        #for t in range(max_t): 
        t =0
        while True:
            actions = []
            for i_agent in range(num_agents):
                actions.append(agent.act(states[i_agent]))
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            for i_agent in range(num_agents):
                agent.step(states[i_agent], actions[i_agent],
                                     rewards[i_agent], next_states[i_agent],
                                     dones[i_agent])
                agent.step_learn()
             
            #agent.update_t_step()
            if t % 20 ==0:
                #print ("time{} and step yes".format(t))
                for i in range(10):
                    agent.step_learn()
            
            states = next_states
            scores += rewards
            t += 1
            if np.any(dones):
                print('\tSteps: ', t)
                t=0
                break 
        
        scores_deque.append(np.mean(scores))
        scores_list.append(np.mean(scores))
        
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)), end="")
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
        
        if np.mean(scores_deque) >= 30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode, np.mean(scores_deque)))
            agent.checkpoint()
            break
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(1, len(scores_list)+1), scores_list)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================


#================ Hyperpramters =========================

BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 128        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_1= 256          #Actor Hidden layer 1
ACTOR_HL_2= 128          #Actor Hidden layer 1

CRITIC_HL_1= 256          #Actor Hidden layer 1
CRITIC_HL_2= 128          #Actor Hidden layer 1

CHECKPOINT_FOLDER = './model_2/'

#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (state_size, action_size, 0,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_1, ACTOR_HL_2, CRITIC_HL_1, CRITIC_HL_2, CHECKPOINT_FOLDER)
ddpg_train()
# Out:
# 	Steps:  1001
# Episode 1	Average Score: 0.00	Steps:  1001
# Episode 2	Average Score: 0.15	Steps:  1001
# Episode 3	Average Score: 0.38	Steps:  1001
# Episode 4	Average Score: 0.41	Steps:  1001
# Episode 5	Average Score: 0.37	Steps:  1001
# Episode 6	Average Score: 0.35	Steps:  1001
# Episode 7	Average Score: 0.37	Steps:  1001
# Episode 8	Average Score: 0.35	Steps:  1001
# Episode 9	Average Score: 0.33	Steps:  1001
# Episode 10	Average Score: 0.40	Steps:  1001
# Episode 11	Average Score: 0.46	Steps:  1001
# Episode 12	Average Score: 0.43	Steps:  1001
# Episode 13	Average Score: 0.41	Steps:  1001
# Episode 14	Average Score: 0.41	Steps:  1001
# Episode 15	Average Score: 0.40	Steps:  1001
# Episode 16	Average Score: 0.39	Steps:  1001
# Episode 17	Average Score: 0.40	Steps:  1001
# Episode 18	Average Score: 0.44	Steps:  1001
# Episode 19	Average Score: 0.41	Steps:  1001
# Episode 20	Average Score: 0.46	Steps:  1001
# Episode 21	Average Score: 0.52	Steps:  1001
# Episode 22	Average Score: 0.53	Steps:  1001
# Episode 23	Average Score: 0.51	Steps:  1001
# Episode 24	Average Score: 0.52	Steps:  1001
# Episode 25	Average Score: 0.50	Steps:  1001
# Episode 26	Average Score: 0.50	Steps:  1001
# Episode 27	Average Score: 0.50	Steps:  1001
# Episode 28	Average Score: 0.54	Steps:  1001
# Episode 29	Average Score: 0.53	Steps:  1001
# Episode 30	Average Score: 0.53	Steps:  1001
# Episode 31	Average Score: 0.51	Steps:  1001
# Episode 32	Average Score: 0.57	Steps:  1001
# Episode 33	Average Score: 0.58	Steps:  1001
# Episode 34	Average Score: 0.57	Steps:  1001
# Episode 35	Average Score: 0.60	Steps:  1001
# Episode 36	Average Score: 0.60	Steps:  1001
# Episode 37	Average Score: 0.62	Steps:  1001
# Episode 38	Average Score: 0.61	Steps:  1001
# Episode 39	Average Score: 0.60	Steps:  1001
# Episode 40	Average Score: 0.60	Steps:  1001
# Episode 41	Average Score: 0.58	Steps:  1001
# Episode 42	Average Score: 0.58	Steps:  1001
# Episode 43	Average Score: 0.58	Steps:  1001
# Episode 44	Average Score: 0.56	Steps:  1001
# Episode 45	Average Score: 0.61	Steps:  1001
# Episode 46	Average Score: 0.61	Steps:  1001
# Episode 47	Average Score: 0.61	Steps:  1001
# Episode 48	Average Score: 0.60	Steps:  1001
# Episode 49	Average Score: 0.62	Steps:  1001
# Episode 50	Average Score: 0.65	Steps:  1001
# Episode 51	Average Score: 0.65	Steps:  1001
# Episode 52	Average Score: 0.65	Steps:  1001
# Episode 53	Average Score: 0.65	Steps:  1001
# Episode 54	Average Score: 0.67	Steps:  1001
# Episode 55	Average Score: 0.67	Steps:  1001
# Episode 56	Average Score: 0.68	Steps:  1001
# Episode 57	Average Score: 0.67	Steps:  1001
# Episode 58	Average Score: 0.69	Steps:  1001
# Episode 59	Average Score: 0.69	Steps:  1001
# Episode 60	Average Score: 0.71	Steps:  1001
# Episode 61	Average Score: 0.71	Steps:  1001
# Episode 62	Average Score: 0.71	Steps:  1001
# Episode 63	Average Score: 0.73	Steps:  1001
# Episode 64	Average Score: 0.73	Steps:  1001
# Episode 65	Average Score: 0.74	Steps:  1001
# Episode 66	Average Score: 0.74	Steps:  1001
# Episode 67	Average Score: 0.75	Steps:  1001
# Episode 68	Average Score: 0.75	Steps:  1001
# Episode 69	Average Score: 0.80	Steps:  1001
# Episode 70	Average Score: 0.82	Steps:  1001
# Episode 71	Average Score: 0.83	Steps:  1001
# Episode 72	Average Score: 0.83	Steps:  1001
# Episode 73	Average Score: 0.84	Steps:  1001
# Episode 74	Average Score: 0.85	Steps:  1001
# Episode 75	Average Score: 0.87	Steps:  1001
# Episode 76	Average Score: 0.86	Steps:  1001
# Episode 77	Average Score: 0.86	Steps:  1001
# Episode 78	Average Score: 0.87	Steps:  1001
# Episode 79	Average Score: 0.88	Steps:  1001
# Episode 80	Average Score: 0.88	Steps:  1001
# Episode 81	Average Score: 0.89	Steps:  1001
# Episode 82	Average Score: 0.90	Steps:  1001
# Episode 83	Average Score: 0.90	Steps:  1001
# Episode 84	Average Score: 0.89	Steps:  1001
# Episode 85	Average Score: 0.90	Steps:  1001
# Episode 86	Average Score: 0.91	Steps:  1001
# Episode 87	Average Score: 0.92	Steps:  1001
# Episode 88	Average Score: 0.91	Steps:  1001
# Episode 89	Average Score: 0.91	Steps:  1001
# Episode 90	Average Score: 0.93	Steps:  1001
# Episode 91	Average Score: 0.93	Steps:  1001
# Episode 92	Average Score: 0.93	Steps:  1001
# Episode 93	Average Score: 0.94	Steps:  1001
# Episode 94	Average Score: 0.94	Steps:  1001
# Episode 95	Average Score: 0.95	Steps:  1001
# Episode 96	Average Score: 0.96	Steps:  1001
# Episode 97	Average Score: 0.99	Steps:  1001
# Episode 98	Average Score: 1.00	Steps:  1001
# Episode 99	Average Score: 1.01	Steps:  1001
# Episode 100	Average Score: 1.02
# 	Steps:  1001
# Episode 101	Average Score: 1.03	Steps:  1001
# Episode 102	Average Score: 1.04	Steps:  1001
# Episode 103	Average Score: 1.07	Steps:  1001
# Episode 104	Average Score: 1.07	Steps:  1001
# Episode 105	Average Score: 1.08	Steps:  1001
# Episode 106	Average Score: 1.10	Steps:  1001
# Episode 107	Average Score: 1.11	Steps:  1001
# Episode 108	Average Score: 1.13	Steps:  1001
# Episode 109	Average Score: 1.16	Steps:  1001
# Episode 110	Average Score: 1.18	Steps:  1001
# Episode 111	Average Score: 1.19	Steps:  1001
# Episode 112	Average Score: 1.21	Steps:  1001
# Episode 113	Average Score: 1.23	Steps:  1001
# Episode 114	Average Score: 1.26	Steps:  1001
# Episode 115	Average Score: 1.26	Steps:  1001
# Episode 116	Average Score: 1.29	Steps:  1001
# Episode 117	Average Score: 1.31	Steps:  1001
# Episode 118	Average Score: 1.35	Steps:  1001
# Episode 119	Average Score: 1.37	Steps:  1001
# Episode 120	Average Score: 1.37	Steps:  1001
# Episode 121	Average Score: 1.36	Steps:  1001
# Episode 122	Average Score: 1.36	Steps:  1001
# Episode 123	Average Score: 1.37	Steps:  1001
# Episode 124	Average Score: 1.37	Steps:  1001
# Episode 125	Average Score: 1.38	Steps:  1001
# Episode 126	Average Score: 1.42	Steps:  1001
# Episode 127	Average Score: 1.43	Steps:  1001
# Episode 128	Average Score: 1.45	Steps:  1001
# Episode 129	Average Score: 1.46	Steps:  1001
# Episode 130	Average Score: 1.48	Steps:  1001
# Episode 131	Average Score: 1.49	Steps:  1001
# Episode 132	Average Score: 1.49	Steps:  1001
# Episode 133	Average Score: 1.49	Steps:  1001
# Episode 134	Average Score: 1.49	Steps:  1001
# Episode 135	Average Score: 1.49	Steps:  1001
# Episode 136	Average Score: 1.52	Steps:  1001
# Episode 137	Average Score: 1.52	Steps:  1001
# Episode 138	Average Score: 1.53	Steps:  1001
# Episode 139	Average Score: 1.54	Steps:  1001
# Episode 140	Average Score: 1.55	Steps:  1001
# Episode 141	Average Score: 1.56	Steps:  1001
# Episode 142	Average Score: 1.59	Steps:  1001
# Episode 143	Average Score: 1.59	Steps:  1001
# Episode 144	Average Score: 1.61	Steps:  1001
# Episode 145	Average Score: 1.62	Steps:  1001
# Episode 146	Average Score: 1.63	Steps:  1001
# Episode 147	Average Score: 1.64	Steps:  1001
# Episode 148	Average Score: 1.65	Steps:  1001
# Episode 149	Average Score: 1.67	Steps:  1001
# Episode 150	Average Score: 1.66	Steps:  1001
# Episode 151	Average Score: 1.68	Steps:  1001
# Episode 152	Average Score: 1.69	Steps:  1001
# Episode 153	Average Score: 1.71	Steps:  1001
# Episode 154	Average Score: 1.71	Steps:  1001
# Episode 155	Average Score: 1.72	Steps:  1001
# Episode 156	Average Score: 1.72	Steps:  1001
# Episode 157	Average Score: 1.73	Steps:  1001
# Episode 158	Average Score: 1.73	Steps:  1001
# Episode 159	Average Score: 1.76	Steps:  1001
# Episode 160	Average Score: 1.75	Steps:  1001
# Episode 161	Average Score: 1.75	Steps:  1001
# Episode 162	Average Score: 1.76	Steps:  1001
# Episode 163	Average Score: 1.76	Steps:  1001
# Episode 164	Average Score: 1.78	Steps:  1001
# Episode 165	Average Score: 1.77	Steps:  1001
# Episode 166	Average Score: 1.78	Steps:  1001
# Episode 167	Average Score: 1.78	Steps:  1001
# Episode 168	Average Score: 1.78	Steps:  1001
# Episode 169	Average Score: 1.76	Steps:  1001
# Episode 170	Average Score: 1.77	Steps:  1001
# Episode 171	Average Score: 1.77	Steps:  1001
# Episode 172	Average Score: 1.78	Steps:  1001
# Episode 173	Average Score: 1.78	Steps:  1001
# Episode 174	Average Score: 1.78	Steps:  1001
# Episode 175	Average Score: 1.77	Steps:  1001
# Episode 176	Average Score: 1.78	Steps:  1001
# Episode 177	Average Score: 1.81	Steps:  1001
# Episode 178	Average Score: 1.81	Steps:  1001
# Episode 179	Average Score: 1.80	Steps:  1001
# Episode 180	Average Score: 1.81	Steps:  1001
# Episode 181	Average Score: 1.80	Steps:  1001
# Episode 182	Average Score: 1.81	Steps:  1001
# Episode 183	Average Score: 1.81	Steps:  1001
# Episode 184	Average Score: 1.82	Steps:  1001
# Episode 185	Average Score: 1.82	Steps:  1001
# Episode 186	Average Score: 1.81	Steps:  1001
# Episode 187	Average Score: 1.82	Steps:  1001
# Episode 188	Average Score: 1.83	Steps:  1001
# Episode 189	Average Score: 1.84	Steps:  1001
# Episode 190	Average Score: 1.84	Steps:  1001
# Episode 191	Average Score: 1.84	Steps:  1001
# Episode 192	Average Score: 1.83	Steps:  1001
# Episode 193	Average Score: 1.85	Steps:  1001
# Episode 194	Average Score: 1.85	Steps:  1001
# Episode 195	Average Score: 1.85	Steps:  1001
# Episode 196	Average Score: 1.84	Steps:  1001
# Episode 197	Average Score: 1.82	Steps:  1001
# Episode 198	Average Score: 1.82	Steps:  1001
# Episode 199	Average Score: 1.81	Steps:  1001
# Episode 200	Average Score: 1.80
# 	Steps:  1001
# Episode 201	Average Score: 1.82	Steps:  1001
# Episode 202	Average Score: 1.83	Steps:  1001
# Episode 203	Average Score: 1.82	Steps:  1001
# Episode 204	Average Score: 1.83	Steps:  1001
# Episode 205	Average Score: 1.84	Steps:  1001
# Episode 206	Average Score: 1.85	Steps:  1001
# Episode 207	Average Score: 1.85	Steps:  1001
# Episode 208	Average Score: 1.85	Steps:  1001
# Episode 209	Average Score: 1.84	Steps:  1001
# Episode 210	Average Score: 1.85	Steps:  1001
# Episode 211	Average Score: 1.84	Steps:  1001
# Episode 212	Average Score: 1.85	Steps:  1001
# Episode 213	Average Score: 1.86	Steps:  1001
# Episode 214	Average Score: 1.85	Steps:  1001
# Episode 215	Average Score: 1.86	Steps:  1001
# Episode 216	Average Score: 1.83	Steps:  1001
# Episode 217	Average Score: 1.82	Steps:  1001
# Episode 218	Average Score: 1.78	Steps:  1001
# Episode 219	Average Score: 1.79	Steps:  1001
# Episode 220	Average Score: 1.81	Steps:  1001
# Episode 221	Average Score: 1.82	Steps:  1001
# Episode 222	Average Score: 1.82	Steps:  1001
# Episode 223	Average Score: 1.83	Steps:  1001
# Episode 224	Average Score: 1.85	Steps:  1001
# Episode 225	Average Score: 1.86	Steps:  1001
# Episode 226	Average Score: 1.84	Steps:  1001
# Episode 227	Average Score: 1.84	Steps:  1001
# Episode 228	Average Score: 1.84	Steps:  1001
# Episode 229	Average Score: 1.83	Steps:  1001
# Episode 230	Average Score: 1.83	Steps:  1001
# Episode 231	Average Score: 1.84	Steps:  1001
# Episode 232	Average Score: 1.84	Steps:  1001
# Episode 233	Average Score: 1.84	Steps:  1001
# Episode 234	Average Score: 1.86	Steps:  1001
# Episode 235	Average Score: 1.85	Steps:  1001
# Episode 236	Average Score: 1.85	Steps:  1001
# Episode 237	Average Score: 1.86	Steps:  1001
# Episode 238	Average Score: 1.87	Steps:  1001
# Episode 239	Average Score: 1.87	Steps:  1001
# Episode 240	Average Score: 1.88	Steps:  1001
# Episode 241	Average Score: 1.89	Steps:  1001
# Episode 242	Average Score: 1.88	Steps:  1001
# Episode 243	Average Score: 1.90	Steps:  1001
# Episode 244	Average Score: 1.91	Steps:  1001
# Episode 245	Average Score: 1.89	Steps:  1001
# Episode 246	Average Score: 1.90	Steps:  1001
# Episode 247	Average Score: 1.91	Steps:  1001
# Episode 248	Average Score: 1.93	Steps:  1001
# Episode 249	Average Score: 1.91	Steps:  1001
# Episode 250	Average Score: 1.92	Steps:  1001
# Episode 251	Average Score: 1.91	Steps:  1001
# Episode 252	Average Score: 1.91	Steps:  1001
# Episode 253	Average Score: 1.93	Steps:  1001
# Episode 254	Average Score: 1.91	Steps:  1001
# Episode 255	Average Score: 1.92	Steps:  1001
# Episode 256	Average Score: 1.94	Steps:  1001
# Episode 257	Average Score: 1.93	Steps:  1001
# Episode 258	Average Score: 1.93	Steps:  1001
# Episode 259	Average Score: 1.91	Steps:  1001
# Episode 260	Average Score: 1.92	Steps:  1001
# Episode 261	Average Score: 1.92	Steps:  1001
# Episode 262	Average Score: 1.93	Steps:  1001
# Episode 263	Average Score: 1.92	Steps:  1001
# Episode 264	Average Score: 1.92	Steps:  1001
# Episode 265	Average Score: 1.95	Steps:  1001
# Episode 266	Average Score: 1.94	Steps:  1001
# Episode 267	Average Score: 1.95	Steps:  1001
# Episode 268	Average Score: 1.94	Steps:  1001
# Episode 269	Average Score: 1.93	Steps:  1001
# Episode 270	Average Score: 1.92	Steps:  1001
# Episode 271	Average Score: 1.92	Steps:  1001
# Episode 272	Average Score: 1.92	Steps:  1001
# Episode 273	Average Score: 1.92	Steps:  1001
# Episode 274	Average Score: 1.91	Steps:  1001
# Episode 275	Average Score: 1.91	Steps:  1001
# Episode 276	Average Score: 1.92	Steps:  1001
# Episode 277	Average Score: 1.90	Steps:  1001
# Episode 278	Average Score: 1.89	Steps:  1001
# Episode 279	Average Score: 1.91	Steps:  1001
# Episode 280	Average Score: 1.92	Steps:  1001
# Episode 281	Average Score: 1.92	Steps:  1001
# Episode 282	Average Score: 1.92	Steps:  1001
# Episode 283	Average Score: 1.94	Steps:  1001
# Episode 284	Average Score: 1.95	Steps:  1001
# Episode 285	Average Score: 1.95	Steps:  1001
# Episode 286	Average Score: 1.94	Steps:  1001
# Episode 287	Average Score: 1.93	Steps:  1001
# Episode 288	Average Score: 1.95	Steps:  1001
# Episode 289	Average Score: 1.93	Steps:  1001
# Episode 290	Average Score: 1.93	Steps:  1001
# Episode 291	Average Score: 1.95	Steps:  1001
# Episode 292	Average Score: 1.96	Steps:  1001
# Episode 293	Average Score: 1.94	Steps:  1001
# Episode 294	Average Score: 1.95	Steps:  1001
# Episode 295	Average Score: 1.93	Steps:  1001
# Episode 296	Average Score: 1.94	Steps:  1001
# Episode 297	Average Score: 1.95	Steps:  1001
# Episode 298	Average Score: 1.93	Steps:  1001
# Episode 299	Average Score: 1.95	Steps:  1001
# Episode 300	Average Score: 1.95

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================


#================ Hyperpramters =========================

BUFFER_SIZE = int(1e3)  # replay buffer size
BATCH_SIZE = 64        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_1= 256          #Actor Hidden layer 1
ACTOR_HL_2= 128          #Actor Hidden layer 1

CRITIC_HL_1= 256          #Actor Hidden layer 1
CRITIC_HL_2= 128          #Actor Hidden layer 1

CHECKPOINT_FOLDER = './model_2/'

#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (state_size, action_size, 0,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_1, ACTOR_HL_2, CRITIC_HL_1, CRITIC_HL_2, CHECKPOINT_FOLDER)
ddpg_train()
# Out:
# 	Steps:  1001
# Episode 1	Average Score: 0.11	Steps:  1001
# Episode 2	Average Score: 0.12	Steps:  1001
# Episode 3	Average Score: 0.11	Steps:  1001
# Episode 4	Average Score: 0.13	Steps:  1001
# Episode 5	Average Score: 0.14	Steps:  1001
# Episode 6	Average Score: 0.15	Steps:  1001
# Episode 7	Average Score: 0.20	Steps:  1001
# Episode 8	Average Score: 0.19	Steps:  1001
# Episode 9	Average Score: 0.21	Steps:  1001
# Episode 10	Average Score: 0.20	Steps:  1001
# Episode 11	Average Score: 0.28	Steps:  1001
# Episode 12	Average Score: 0.26	Steps:  1001
# Episode 13	Average Score: 0.28	Steps:  1001
# Episode 14	Average Score: 0.26	Steps:  1001
# Episode 15	Average Score: 0.24	Steps:  1001
# Episode 16	Average Score: 0.23	Steps:  1001
# Episode 17	Average Score: 0.21	Steps:  1001
# Episode 18	Average Score: 0.20	Steps:  1001
# Episode 19	Average Score: 0.19	Steps:  1001
# Episode 20	Average Score: 0.18	Steps:  1001
# Episode 21	Average Score: 0.17	Steps:  1001
# Episode 22	Average Score: 0.16	Steps:  1001
# Episode 23	Average Score: 0.16	Steps:  1001
# Episode 24	Average Score: 0.15	Steps:  1001
# Episode 25	Average Score: 0.14	Steps:  1001
# Episode 26	Average Score: 0.14	Steps:  1001
# Episode 27	Average Score: 0.16	Steps:  1001
# Episode 28	Average Score: 0.15	Steps:  1001
# Episode 29	Average Score: 0.15	Steps:  1001
# Episode 30	Average Score: 0.14	Steps:  1001
# Episode 31	Average Score: 0.14	Steps:  1001
# Episode 32	Average Score: 0.13	Steps:  1001
# Episode 33	Average Score: 0.13	Steps:  1001
# Episode 34	Average Score: 0.13	Steps:  1001
# Episode 35	Average Score: 0.12	Steps:  1001
# Episode 36	Average Score: 0.12	Steps:  1001
# Episode 37	Average Score: 0.12	Steps:  1001
# Episode 38	Average Score: 0.11	Steps:  1001
# Episode 39	Average Score: 0.11	Steps:  1001
# Episode 40	Average Score: 0.11	Steps:  1001
# Episode 41	Average Score: 0.11	Steps:  1001
# Episode 42	Average Score: 0.10	Steps:  1001
# Episode 43	Average Score: 0.10	Steps:  1001
# Episode 44	Average Score: 0.10	Steps:  1001
# Episode 45	Average Score: 0.10	Steps:  1001
# Episode 46	Average Score: 0.09	Steps:  1001
# Episode 47	Average Score: 0.09	Steps:  1001
# Episode 48	Average Score: 0.10	Steps:  1001
# Episode 49	Average Score: 0.10	Steps:  1001
# Episode 50	Average Score: 0.10	Steps:  1001
# Episode 51	Average Score: 0.10	Steps:  1001
# Episode 52	Average Score: 0.10	Steps:  1001
# Episode 53	Average Score: 0.10	Steps:  1001
# Episode 54	Average Score: 0.10	Steps:  1001
# Episode 55	Average Score: 0.10	Steps:  1001
# Episode 56	Average Score: 0.10	Steps:  1001
# Episode 57	Average Score: 0.10	Steps:  1001
# Episode 58	Average Score: 0.10	Steps:  1001
# Episode 59	Average Score: 0.10	Steps:  1001
# Episode 60	Average Score: 0.10	Steps:  1001
# Episode 61	Average Score: 0.10	Steps:  1001
# Episode 62	Average Score: 0.10	Steps:  1001
# Episode 63	Average Score: 0.09	Steps:  1001
# Episode 64	Average Score: 0.09	Steps:  1001
# Episode 65	Average Score: 0.09	Steps:  1001
# Episode 66	Average Score: 0.09	Steps:  1001
# Episode 67	Average Score: 0.09	Steps:  1001
# Episode 68	Average Score: 0.09	Steps:  1001
# Episode 69	Average Score: 0.09	Steps:  1001
# Episode 70	Average Score: 0.09	Steps:  1001
# Episode 71	Average Score: 0.09	Steps:  1001
# Episode 72	Average Score: 0.09	Steps:  1001
# Episode 73	Average Score: 0.09	Steps:  1001
# Episode 74	Average Score: 0.09	Steps:  1001
# Episode 75	Average Score: 0.10	Steps:  1001
# Episode 76	Average Score: 0.10	Steps:  1001
# Episode 77	Average Score: 0.10	Steps:  1001
# Episode 78	Average Score: 0.10	Steps:  1001
# Episode 79	Average Score: 0.10	Steps:  1001
# Episode 80	Average Score: 0.10	Steps:  1001
# Episode 81	Average Score: 0.10	Steps:  1001
# Episode 82	Average Score: 0.10	Steps:  1001
# Episode 83	Average Score: 0.10	Steps:  1001
# Episode 84	Average Score: 0.10	Steps:  1001
# Episode 85	Average Score: 0.10	Steps:  1001
# Episode 86	Average Score: 0.10	Steps:  1001
# Episode 87	Average Score: 0.10	Steps:  1001
# Episode 88	Average Score: 0.10	Steps:  1001
# Episode 89	Average Score: 0.10	Steps:  1001
# Episode 90	Average Score: 0.09	Steps:  1001
# Episode 91	Average Score: 0.10	Steps:  1001
# Episode 92	Average Score: 0.10	Steps:  1001
# Episode 93	Average Score: 0.10	Steps:  1001
# Episode 94	Average Score: 0.10	Steps:  1001
# Episode 95	Average Score: 0.10	Steps:  1001
# Episode 96	Average Score: 0.11	Steps:  1001
# Episode 97	Average Score: 0.12	Steps:  1001
# Episode 98	Average Score: 0.12	Steps:  1001
# Episode 99	Average Score: 0.12	Steps:  1001
# Episode 100	Average Score: 0.13
# 	Steps:  1001
# Episode 101	Average Score: 0.14	Steps:  1001
# Episode 102	Average Score: 0.14	Steps:  1001
# Episode 103	Average Score: 0.15	Steps:  1001
# Episode 104	Average Score: 0.16	Steps:  1001
# Episode 105	Average Score: 0.17	Steps:  1001
# Episode 106	Average Score: 0.18	Steps:  1001
# Episode 107	Average Score: 0.19	Steps:  1001
# Episode 108	Average Score: 0.19	Steps:  1001
# Episode 109	Average Score: 0.18	Steps:  1001
# Episode 110	Average Score: 0.18	Steps:  1001
# Episode 111	Average Score: 0.18	Steps:  1001
# Episode 112	Average Score: 0.18	Steps:  1001
# Episode 113	Average Score: 0.19	Steps:  1001
# Episode 114	Average Score: 0.20	Steps:  1001
# Episode 115	Average Score: 0.20	Steps:  1001
# Episode 116	Average Score: 0.22	Steps:  1001
# Episode 117	Average Score: 0.23	Steps:  1001
# Episode 118	Average Score: 0.23	Steps:  1001
# Episode 119	Average Score: 0.24	Steps:  1001
# Episode 120	Average Score: 0.26	Steps:  1001
# Episode 121	Average Score: 0.27	Steps:  1001
# Episode 122	Average Score: 0.27	Steps:  1001
# Episode 123	Average Score: 0.28	Steps:  1001
# Episode 124	Average Score: 0.29	Steps:  1001
# Episode 125	Average Score: 0.29	Steps:  1001
# Episode 126	Average Score: 0.30	Steps:  1001
# Episode 127	Average Score: 0.30	Steps:  1001
# Episode 128	Average Score: 0.30	Steps:  1001
# Episode 129	Average Score: 0.31	Steps:  1001
# Episode 130	Average Score: 0.32	Steps:  1001
# Episode 131	Average Score: 0.33	Steps:  1001
# Episode 132	Average Score: 0.33	Steps:  1001
# Episode 133	Average Score: 0.34	Steps:  1001
# Episode 134	Average Score: 0.35	Steps:  1001
# Episode 135	Average Score: 0.35	Steps:  1001
# Episode 136	Average Score: 0.36	Steps:  1001
# Episode 137	Average Score: 0.36	Steps:  1001
# Episode 138	Average Score: 0.37	Steps:  1001
# Episode 139	Average Score: 0.37	Steps:  1001
# Episode 140	Average Score: 0.38	Steps:  1001
# Episode 141	Average Score: 0.39	Steps:  1001
# Episode 142	Average Score: 0.39	Steps:  1001
# Episode 143	Average Score: 0.40	Steps:  1001
# Episode 144	Average Score: 0.40	Steps:  1001
# Episode 145	Average Score: 0.41	Steps:  1001
# Episode 146	Average Score: 0.41	Steps:  1001
# Episode 147	Average Score: 0.41	Steps:  1001
# Episode 148	Average Score: 0.41	Steps:  1001
# Episode 149	Average Score: 0.41	Steps:  1001
# Episode 150	Average Score: 0.41	Steps:  1001
# Episode 151	Average Score: 0.42	Steps:  1001
# Episode 152	Average Score: 0.43	Steps:  1001
# Episode 153	Average Score: 0.43	Steps:  1001
# Episode 154	Average Score: 0.43	Steps:  1001
# Episode 155	Average Score: 0.44	Steps:  1001
# Episode 156	Average Score: 0.44	Steps:  1001
# Episode 157	Average Score: 0.45	Steps:  1001
# Episode 158	Average Score: 0.46	Steps:  1001
# Episode 159	Average Score: 0.47	Steps:  1001
# Episode 160	Average Score: 0.47	Steps:  1001
# Episode 161	Average Score: 0.47	Steps:  1001
# Episode 162	Average Score: 0.48	Steps:  1001
# Episode 163	Average Score: 0.48	Steps:  1001
# Episode 164	Average Score: 0.49	Steps:  1001
# Episode 165	Average Score: 0.49	Steps:  1001
# Episode 166	Average Score: 0.50	Steps:  1001
# Episode 167	Average Score: 0.51	Steps:  1001
# Episode 168	Average Score: 0.51	Steps:  1001
# Episode 169	Average Score: 0.52	Steps:  1001
# Episode 170	Average Score: 0.53	Steps:  1001
# Episode 171	Average Score: 0.53	Steps:  1001
# Episode 172	Average Score: 0.54	Steps:  1001
# Episode 173	Average Score: 0.54	Steps:  1001
# Episode 174	Average Score: 0.54	Steps:  1001
# Episode 175	Average Score: 0.53	Steps:  1001
# Episode 176	Average Score: 0.53	Steps:  1001
# Episode 177	Average Score: 0.53	Steps:  1001
# Episode 178	Average Score: 0.53	Steps:  1001
# Episode 179	Average Score: 0.53	Steps:  1001
# Episode 180	Average Score: 0.53	Steps:  1001
# Episode 181	Average Score: 0.53	Steps:  1001
# Episode 182	Average Score: 0.53	Steps:  1001
# Episode 183	Average Score: 0.53	Steps:  1001
# Episode 184	Average Score: 0.53	Steps:  1001
# Episode 185	Average Score: 0.53	Steps:  1001
# Episode 186	Average Score: 0.53	Steps:  1001
# Episode 187	Average Score: 0.53	Steps:  1001
# Episode 188	Average Score: 0.53	Steps:  1001
# Episode 189	Average Score: 0.54	Steps:  1001
# Episode 190	Average Score: 0.56	Steps:  1001
# Episode 191	Average Score: 0.56	Steps:  1001
# Episode 192	Average Score: 0.57	Steps:  1001
# Episode 193	Average Score: 0.57	Steps:  1001
# Episode 194	Average Score: 0.57	Steps:  1001
# Episode 195	Average Score: 0.58	Steps:  1001
# Episode 196	Average Score: 0.58	Steps:  1001
# Episode 197	Average Score: 0.58	Steps:  1001
# Episode 198	Average Score: 0.58	Steps:  1001
# Episode 199	Average Score: 0.58	Steps:  1001
# Episode 200	Average Score: 0.58
# 	Steps:  1001
# Episode 201	Average Score: 0.57	Steps:  1001
# Episode 202	Average Score: 0.58	Steps:  1001
# Episode 203	Average Score: 0.57	Steps:  1001
# Episode 204	Average Score: 0.56	Steps:  1001
# Episode 205	Average Score: 0.55	Steps:  1001
# Episode 206	Average Score: 0.55	Steps:  1001
# Episode 207	Average Score: 0.54	Steps:  1001
# Episode 208	Average Score: 0.54	Steps:  1001
# Episode 209	Average Score: 0.54	Steps:  1001
# Episode 210	Average Score: 0.55	Steps:  1001
# Episode 211	Average Score: 0.55	Steps:  1001
# Episode 212	Average Score: 0.55	Steps:  1001
# Episode 213	Average Score: 0.53	Steps:  1001
# Episode 214	Average Score: 0.52	Steps:  1001
# Episode 215	Average Score: 0.52	Steps:  1001
# Episode 216	Average Score: 0.50	Steps:  1001
# Episode 217	Average Score: 0.50	Steps:  1001
# Episode 218	Average Score: 0.49	Steps:  1001
# Episode 219	Average Score: 0.49	Steps:  1001
# Episode 220	Average Score: 0.47	Steps:  1001
# Episode 221	Average Score: 0.46	Steps:  1001
# Episode 222	Average Score: 0.45	Steps:  1001
# Episode 223	Average Score: 0.45	Steps:  1001
# Episode 224	Average Score: 0.44	Steps:  1001
# Episode 225	Average Score: 0.43	Steps:  1001
# Episode 226	Average Score: 0.43	Steps:  1001
# Episode 227	Average Score: 0.42	Steps:  1001
# Episode 228	Average Score: 0.42	Steps:  1001
# Episode 229	Average Score: 0.41	Steps:  1001
# Episode 230	Average Score: 0.40	Steps:  1001
# Episode 231	Average Score: 0.40	Steps:  1001
# Episode 232	Average Score: 0.39	Steps:  1001
# Episode 233	Average Score: 0.38	Steps:  1001
# Episode 234	Average Score: 0.38	Steps:  1001
# Episode 235	Average Score: 0.37	Steps:  1001
# Episode 236	Average Score: 0.36	Steps:  1001
# Episode 237	Average Score: 0.36	Steps:  1001
# Episode 238	Average Score: 0.36	Steps:  1001
# Episode 239	Average Score: 0.35	Steps:  1001
# Episode 240	Average Score: 0.35	Steps:  1001
# Episode 241	Average Score: 0.34	Steps:  1001
# Episode 242	Average Score: 0.33	Steps:  1001
# Episode 243	Average Score: 0.33	Steps:  1001
# Episode 244	Average Score: 0.33	Steps:  1001
# Episode 245	Average Score: 0.32	Steps:  1001
# Episode 246	Average Score: 0.32	Steps:  1001
# Episode 247	Average Score: 0.32	Steps:  1001
# Episode 248	Average Score: 0.32	Steps:  1001
# Episode 249	Average Score: 0.31	Steps:  1001
# Episode 250	Average Score: 0.31	Steps:  1001
# Episode 251	Average Score: 0.30	Steps:  1001
# Episode 252	Average Score: 0.30	Steps:  1001
# Episode 253	Average Score: 0.29	Steps:  1001
# Episode 254	Average Score: 0.29	Steps:  1001
# Episode 255	Average Score: 0.28	Steps:  1001
# Episode 256	Average Score: 0.28	Steps:  1001
# Episode 257	Average Score: 0.27	Steps:  1001
# Episode 258	Average Score: 0.26	Steps:  1001
# Episode 259	Average Score: 0.25	Steps:  1001
# Episode 260	Average Score: 0.25	Steps:  1001
# Episode 261	Average Score: 0.25	Steps:  1001
# Episode 262	Average Score: 0.24	Steps:  1001
# Episode 263	Average Score: 0.24	Steps:  1001
# Episode 264	Average Score: 0.23	Steps:  1001
# Episode 265	Average Score: 0.23	Steps:  1001
# Episode 266	Average Score: 0.22	Steps:  1001
# Episode 267	Average Score: 0.21	Steps:  1001
# Episode 268	Average Score: 0.21	Steps:  1001
# Episode 269	Average Score: 0.20	Steps:  1001
# Episode 270	Average Score: 0.19	Steps:  1001
# Episode 271	Average Score: 0.19	Steps:  1001
# Episode 272	Average Score: 0.18	Steps:  1001
# Episode 273	Average Score: 0.18	Steps:  1001
# Episode 274	Average Score: 0.18	Steps:  1001
# Episode 275	Average Score: 0.18	Steps:  1001
# Episode 276	Average Score: 0.18	Steps:  1001
# Episode 277	Average Score: 0.17	Steps:  1001
# Episode 278	Average Score: 0.17	Steps:  1001
# Episode 279	Average Score: 0.18	Steps:  1001
# Episode 280	Average Score: 0.18	Steps:  1001
# Episode 281	Average Score: 0.17	Steps:  1001
# Episode 282	Average Score: 0.17	Steps:  1001
# Episode 283	Average Score: 0.17	Steps:  1001
# Episode 284	Average Score: 0.17	Steps:  1001
# Episode 285	Average Score: 0.17	Steps:  1001
# Episode 286	Average Score: 0.17	Steps:  1001
# Episode 287	Average Score: 0.17	Steps:  1001
# Episode 288	Average Score: 0.17	Steps:  1001
# Episode 289	Average Score: 0.16	Steps:  1001
# Episode 290	Average Score: 0.15	Steps:  1001
# Episode 291	Average Score: 0.13	Steps:  1001
# Episode 292	Average Score: 0.13	Steps:  1001
# Episode 293	Average Score: 0.13	Steps:  1001
# Episode 294	Average Score: 0.12	Steps:  1001
# Episode 295	Average Score: 0.11	Steps:  1001
# Episode 296	Average Score: 0.11	Steps:  1001
# Episode 297	Average Score: 0.10	Steps:  1001
# Episode 298	Average Score: 0.10	Steps:  1001
# Episode 299	Average Score: 0.09	Steps:  1001
# Episode 300	Average Score: 0.08

# %%
#=============================================================
#================ Libraraies =========================
#=============================================================
import random
import copy
import os
from collections import namedtuple, deque

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#=============================================================
#================ The Network  Model =========================
#=============================================================

def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, A_hidden_sizes=[400, 300]):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, A_hidden_sizes[0])
        self.fc2 = nn.Linear(A_hidden_sizes[0], A_hidden_sizes[1])
        self.fc3 = nn.Linear(A_hidden_sizes[1], action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        """Build an actor (policy) network that maps states -> actions."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return F.tanh(self.fc3(x))


class Critic(nn.Module):
    """Critic (Value) Model."""

    def __init__(self, state_size, action_size, seed, C_hidden_sizes=[400, 300]):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fcs1_units (int): Number of nodes in the first hidden layer
            fc2_units (int): Number of nodes in the second hidden layer
        """
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fcs1 = nn.Linear(state_size, C_hidden_sizes[0])
        self.fc2 = nn.Linear(C_hidden_sizes[0]+action_size, C_hidden_sizes[1])
        self.fc3 = nn.Linear(C_hidden_sizes[1], 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcs1.weight.data.uniform_(*hidden_init(self.fcs1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
        xs = F.relu(self.fcs1(state))
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.fc2(x))
        return self.fc3(x)



#=============================================================
#=================== The Agent Class =========================
#=============================================================

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
 

class Agent():
    """Interacts with and learns from the environment."""
    
    def __init__(self, num_agents, state_size, action_size, random_seed,buffer_size, batch_size,gamma, TAU,
                 lr_actor, lr_critic, weight_decay, a_hidden_sizes, c_hidden_sizes):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            random_seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)
        
        # Hyperparameters
        self.BUFFER_SIZE = buffer_size
        self.BATCH_SIZE = batch_size
        self.GAMMA = gamma
        self.TAU = TAU
        self.LR_ACTOR = lr_actor
        self.LR_CRITIC = lr_critic
        self.WEIGHT_DECAY = weight_decay
        self.ACTOR_HL_SIZE= a_hidden_sizes               
        self.CRITIC_HL_SIZE= c_hidden_sizes 
        self.num_agents = num_agents
        

        # Actor Network (w/ Target Network)
        self.actor_local = Actor(state_size, action_size, random_seed,self.ACTOR_HL_SIZE).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed,self.ACTOR_HL_SIZE).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=self.LR_ACTOR)

        # Critic Network (w/ Target Network)
        self.critic_local = Critic(state_size, action_size, random_seed, self.CRITIC_HL_SIZE).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed, self.CRITIC_HL_SIZE).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=self.LR_CRITIC, weight_decay= self.WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)

        # Replay memory
        self.memory = ReplayBuffer(action_size, self.BUFFER_SIZE, self.BATCH_SIZE, random_seed)
        
    
    def step(self, states, actions, rewards, next_states, dones):
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        for i in range(self.num_agents):
            self.memory.add(states[i], actions[i], rewards[i], next_states[i], dones[i])
        
        if len(self.memory) > self.BATCH_SIZE:
            experiences = self.memory.sample()
            self.learn(experiences, self.GAMMA)    

    def act(self, states, add_noise=True):
        """Returns actions for given state as per current policy."""
        states = torch.from_numpy(states).float().to(device)
        actions = np.zeros((self.num_agents, self.action_size))
        self.actor_local.eval()
        with torch.no_grad():
            for i, state in enumerate(states):
                actions[i,:] = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        if add_noise:
            actions += self.noise.sample()
        return np.clip(actions, -1, 1)

    def reset(self):
        self.noise.reset()

    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples.
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value

        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        #torch.nn.utils.clip_grad_norm_(self.critic_local.parameters(), 1)  # adds gradient clipping to stabilize learning
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.soft_update(self.critic_local, self.critic_target, self.TAU)
        self.soft_update(self.actor_local, self.actor_target, self.TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)
        

class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
#=============================================================
#================ Libraraies =========================
#=============================================================
import random
import copy
import os
from collections import namedtuple, deque

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#=============================================================
#================ The Network  Model =========================
#=============================================================

def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, A_hidden_sizes=[400, 300]):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, A_hidden_sizes[0])
        self.fc2 = nn.Linear(A_hidden_sizes[0], A_hidden_sizes[1])
        self.fc3 = nn.Linear(A_hidden_sizes[1], action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        """Build an actor (policy) network that maps states -> actions."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return F.tanh(self.fc3(x))


class Critic(nn.Module):
    """Critic (Value) Model."""

    def __init__(self, state_size, action_size, seed, C_hidden_sizes=[400, 300]):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fcs1_units (int): Number of nodes in the first hidden layer
            fc2_units (int): Number of nodes in the second hidden layer
        """
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fcs1 = nn.Linear(state_size, C_hidden_sizes[0])
        self.fc2 = nn.Linear(C_hidden_sizes[0]+action_size, C_hidden_sizes[1])
        self.fc3 = nn.Linear(C_hidden_sizes[1], 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcs1.weight.data.uniform_(*hidden_init(self.fcs1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
        xs = F.relu(self.fcs1(state))
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.fc2(x))
        return self.fc3(x)



#=============================================================
#=================== The Agent Class =========================
#=============================================================

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
 

class Agent():
    """Interacts with and learns from the environment."""
    
    def __init__(self, num_agents, state_size, action_size, random_seed,buffer_size, batch_size,gamma, TAU,
                 lr_actor, lr_critic, weight_decay, a_hidden_sizes, c_hidden_sizes):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            random_seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)
        
        # Hyperparameters
        self.BUFFER_SIZE = buffer_size
        self.BATCH_SIZE = batch_size
        self.GAMMA = gamma
        self.TAU = TAU
        self.LR_ACTOR = lr_actor
        self.LR_CRITIC = lr_critic
        self.WEIGHT_DECAY = weight_decay
        self.ACTOR_HL_SIZE= a_hidden_sizes               
        self.CRITIC_HL_SIZE= c_hidden_sizes 
        self.num_agents = num_agents
        

        # Actor Network (w/ Target Network)
        self.actor_local = Actor(state_size, action_size, random_seed,self.ACTOR_HL_SIZE).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed,self.ACTOR_HL_SIZE).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=self.LR_ACTOR)

        # Critic Network (w/ Target Network)
        self.critic_local = Critic(state_size, action_size, random_seed, self.CRITIC_HL_SIZE).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed, self.CRITIC_HL_SIZE).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=self.LR_CRITIC, weight_decay= self.WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)

        # Replay memory
        self.memory = ReplayBuffer(action_size, self.BUFFER_SIZE, self.BATCH_SIZE, random_seed)
        
    
    def step(self, state, action, reward, next_state, done):
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        self.memory.add(state, action, reward, next_state, done)
        
        if len(self.memory) > self.BATCH_SIZE:
            experiences = self.memory.sample()
            self.learn(experiences, self.GAMMA)    

    def act(self, state, add_noise=True):
        """Returns actions for given state as per current policy."""
        states = torch.from_numpy(state).float().to(device)
        self.actor_local.eval()
        with torch.no_grad():
            action_values = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        if add_noise:
            action_values += self.noise.sample()
        return np.clip(action_values, -1, 1)

    def reset(self):
        self.noise.reset()

    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples.
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value

        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        #torch.nn.utils.clip_grad_norm_(self.critic_local.parameters(), 1)  # adds gradient clipping to stabilize learning
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.soft_update(self.critic_local, self.critic_target, self.TAU)
        self.soft_update(self.actor_local, self.actor_target, self.TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)
        

class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def ddpg_train(n_episodes=500, max_t=1000, print_every=100):
    scores_deque = deque(maxlen=print_every)
    scores_list = []
    
    for i_episode in range(1, n_episodes+1):
        
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        states = env_info.vector_observations
        scores = np.zeros(num_agents)
        agent.reset()
        
        for t in range(max_t): 
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            agent.step(states, actions, rewards, next_states, dones)
            scores += rewards
            states = next_states
            if np.any(dones):
                print('\tSteps: ', t)
                break 
        average_episode_score = np.mean(scores)
        scores_deque.append(average_episode_score)
        scores_list.append(average_episode_score)
        average_score = np.mean(scores_deque)
        
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, average_score), end="")
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, average_score))
        
        if np.mean(scores_deque) >= 30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode, np.mean(scores_deque)))
            torch.save(agent.actor_local.state_dict(), 'actor_model.pth')
            torch.save(agent.critic_local.state_dict(), 'critic_model.pth')
            break
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(1, len(scores_list)+1), scores_list)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================
#================ Hyperpramters =========================

BUFFER_SIZE = int(1e6)  # replay buffer size
BATCH_SIZE = 512        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 3e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_SIZE= [400, 300]         #Actor Hidden layers
CRITIC_HL_SIZE= [400, 300]          #Critic Hidden layers


#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (num_agents, state_size, action_size, 0,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_SIZE, CRITIC_HL_SIZE)
ddpg_train(n_episodes=450, max_t=1000, print_every=10)
# Out:
# Episode 10	Average Score: 0.97
# Episode 20	Average Score: 3.18
# Episode 30	Average Score: 5.73
# Episode 40	Average Score: 6.91
# Episode 50	Average Score: 9.26
# Episode 60	Average Score: 10.50
# Episode 70	Average Score: 11.27
# Episode 80	Average Score: 12.15
# Episode 90	Average Score: 13.12
# Episode 100	Average Score: 13.04
# Episode 110	Average Score: 14.54
# Episode 120	Average Score: 15.48
# Episode 130	Average Score: 15.29
# Episode 140	Average Score: 14.85
# Episode 150	Average Score: 15.92
# Episode 160	Average Score: 15.89
# Episode 170	Average Score: 16.16
# Episode 180	Average Score: 16.94
# Episode 183	Average Score: 16.98

# %%
#=============================================================
#================ Libraraies =========================
#=============================================================
import random
import copy
import os
from collections import namedtuple, deque

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#=============================================================
#================ The Network  Model =========================
#=============================================================

def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, A_hidden_sizes=[400, 300]):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, A_hidden_sizes[0])
        self.fc2 = nn.Linear(A_hidden_sizes[0], A_hidden_sizes[1])
        self.fc3 = nn.Linear(A_hidden_sizes[1], action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        """Build an actor (policy) network that maps states -> actions."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return F.tanh(self.fc3(x))


class Critic(nn.Module):
    """Critic (Value) Model."""

    def __init__(self, state_size, action_size, seed, C_hidden_sizes=[400, 300]):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fcs1_units (int): Number of nodes in the first hidden layer
            fc2_units (int): Number of nodes in the second hidden layer
        """
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fcs1 = nn.Linear(state_size, C_hidden_sizes[0])
        self.fc2 = nn.Linear(C_hidden_sizes[0]+action_size, C_hidden_sizes[1])
        self.fc3 = nn.Linear(C_hidden_sizes[1], 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcs1.weight.data.uniform_(*hidden_init(self.fcs1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
        xs = F.relu(self.fcs1(state))
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.fc2(x))
        return self.fc3(x)



#=============================================================
#=================== The Agent Class =========================
#=============================================================

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
 

class Agent():
    """Interacts with and learns from the environment."""
    
    def __init__(self, num_agents, state_size, action_size, random_seed,buffer_size, batch_size,gamma, TAU,
                 lr_actor, lr_critic, weight_decay, a_hidden_sizes, c_hidden_sizes):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            random_seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)
        
        # Hyperparameters
        self.BUFFER_SIZE = buffer_size
        self.BATCH_SIZE = batch_size
        self.GAMMA = gamma
        self.TAU = TAU
        self.LR_ACTOR = lr_actor
        self.LR_CRITIC = lr_critic
        self.WEIGHT_DECAY = weight_decay
        self.ACTOR_HL_SIZE= a_hidden_sizes               
        self.CRITIC_HL_SIZE= c_hidden_sizes 
        self.num_agents = num_agents
        

        # Actor Network (w/ Target Network)
        self.actor_local = Actor(state_size, action_size, random_seed,self.ACTOR_HL_SIZE).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed,self.ACTOR_HL_SIZE).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=self.LR_ACTOR)

        # Critic Network (w/ Target Network)
        self.critic_local = Critic(state_size, action_size, random_seed, self.CRITIC_HL_SIZE).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed, self.CRITIC_HL_SIZE).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=self.LR_CRITIC, weight_decay= self.WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)

        # Replay memory
        self.memory = ReplayBuffer(action_size, self.BUFFER_SIZE, self.BATCH_SIZE, random_seed)
        
    
    def step(self, states, actions, rewards, next_states, dones):
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        for i in range(states.shape[0]):
            self.memory.add(states[i], actions[i], rewards[i], next_states[i], dones[i])
        
        if len(self.memory) > self.BATCH_SIZE:
            experiences = self.memory.sample()
            self.learn(experiences, self.GAMMA)    

    def act(self, states, add_noise=True):
        """Returns actions for given state as per current policy."""
        states = torch.from_numpy(states).float().to(device)
        self.actor_local.eval()
        with torch.no_grad():
            action_values = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        if add_noise:
            action_values += self.noise.sample()
        return np.clip(actions, -1, 1)


    def reset(self):
        self.noise.reset()

    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples.
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value

        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        #torch.nn.utils.clip_grad_norm_(self.critic_local.parameters(), 1)  # adds gradient clipping to stabilize learning
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.soft_update(self.critic_local, self.critic_target, self.TAU)
        self.soft_update(self.actor_local, self.actor_target, self.TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)
        

class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def ddpg_train(n_episodes=500, max_t=1000, print_every=100):
    scores_deque = deque(maxlen=print_every)
    scores_list = []
    
    for i_episode in range(1, n_episodes+1):
        
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        states = env_info.vector_observations
        scores = np.zeros(num_agents)
        agent.reset()
        
        for t in range(max_t): 
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            agent.step(states, actions, rewards, next_states, dones)
            scores += rewards
            states = next_states
            if np.any(dones):
                print('\tSteps: ', t)
                break 
        average_episode_score = np.mean(scores)
        scores_deque.append(average_episode_score)
        scores_list.append(average_episode_score)
        average_score = np.mean(scores_deque)
        
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, average_score), end="")
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, average_score))
        
        if np.mean(scores_deque) >= 30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode, np.mean(scores_deque)))
            torch.save(agent.actor_local.state_dict(), 'actor_model.pth')
            torch.save(agent.critic_local.state_dict(), 'critic_model.pth')
            break
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(1, len(scores_list)+1), scores_list)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()

# %%
#==================================================================
#======================Main Program Call===========================
#==================================================================
#================ Hyperpramters =========================

BUFFER_SIZE = int(1e6)  # replay buffer size
BATCH_SIZE = 512        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 3e-4        # learning rate of the critic
WEIGHT_DECAY = 0   # L2 weight decay

ACTOR_HL_SIZE= [400, 300]         #Actor Hidden layers
CRITIC_HL_SIZE= [400, 300]          #Critic Hidden layers


#Creating an Agent with statesize and action size matching the enivorment given parameters [State = 33, actions=4]
agent = Agent (num_agents, state_size, action_size, 0,
               BUFFER_SIZE, BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, WEIGHT_DECAY,
              ACTOR_HL_SIZE, CRITIC_HL_SIZE)
ddpg_train(n_episodes=450, max_t=1000, print_every=10)
